# %%
import pandas as pd
import numpy as np
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %%
test = pd.read_csv('../data/out/predictions.csv')

target='Property Benefits ($)'
xcols = [c for c in test.columns if c not in ['prediction',target]]

# %%
model = joblib.load('../data/out/model.joblib')

# %% [markdown]
# ### How did it score? bad? yeah!

# %%
print('R2 SCORE: ', model.score(test[xcols],test[target]))
# Out:
# R2 SCORE:  0.37159612544174536

# %%
sns.lmplot(test, x=target, y='prediction', scatter_kws={'alpha':0.3,'s':5})
plt.show()
